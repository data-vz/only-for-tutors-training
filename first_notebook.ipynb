# %% [markdown]
# My first notebook
# # Coding training
# ## Python

# %%
print('Python is cool')
# Out:
# Python is cool

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 2.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.3 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/12.3 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.3 MB 2.0 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.3 MB 1.8 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.3 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.1/12.3 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/12.3 MB 1.9 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.3 MB 1.8 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.3 MB 1.8 MB/s eta 0:00:05
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 5.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 5.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 5.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 5.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 5.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.3 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.8 MB/s  0:00:00
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
plt.plot(np.tan(range(10)))

# %%
1000+6000
# Out:
# 7000
